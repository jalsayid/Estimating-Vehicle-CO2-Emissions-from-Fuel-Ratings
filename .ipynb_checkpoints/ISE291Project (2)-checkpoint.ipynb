# %% [markdown]
# # ISE 291 PROJECT

# %% [markdown]
# ***Group 04***
# ***
# ***Section F17***
# ***
# ***Group members***
# * Aishah algharib
# * Budoor Salem
# * Danah Alotaibi
# * Najla Aljaloud
# * Joud Alsayid

# %% [markdown]
# # Introduction

# %% [markdown]
# With the overwhelming amount of information obtainable today, businesses and other entities are challenged with an endless flow of new data emerging. Data analytics is becoming more critical than any time in revealing the valuable information hidden within this quantity of raw data. the ability to analyze data is a crucial aspect of success as it allows those in charge to acquire useful information, discover trends, and develop educated plans of action.
#
# Our aim is to make use of the data analytics life cycle with utmost accuracy so as to uncover the untapped values of our chosen topic and contribute to a greater recognition of its significance.
#
# Our project conforms to a nicely laid out data analytics life cycle which consists of multiple essential phases, outlined as follows:

# %% [markdown]
# # Phase1: Discovery

# %% [markdown]
# Data Set: Fuel consumption ratings and estimated carbon dioxide emissions for new vehicles
#
# File Name: Fuel Consumption Ratings 2023.xlsx
#
# From: https://www.kaggle.com/datasets
#
# This data set shows a comprehensive collection of informaton related to fuel consumption ratings and estimated carbon dioxide emissions for new vehicles.It include details such as engine size, cylinders, transmission, fuel type, fuel, and combined fuel consumption rating. This dataset enables researchers to analyze and understand the relationships between these variables and their impact on fuel consumption ratings and estimated carbon dioxide emissions for new light-duty vehicles for retail sale in Canada.
#
# Problem: Fuel consumption is an important issue worldwide as a result of its effect on the environment  especially in relation to climate change that causes Arctic ice caps to melt, sea-level to rise, and extreme weather events.. Being aware of the fuel consumption ratings and predicted CO2 emissions of recently introduced vehicles is vital considering the rising awareness of global warming and the demand for environmentally friendly practices.
#
# Objective: The goal of this project is to address the pressing issue of high fuel consumption and CO2 emissions in the recently introduced automobiles as well as provide stakeholders including consumers and lawmakers with significant points of view. The dataset includes essential attributes, such as the engine size, cylinders, transmission, fuel type, fuel consumption, Highway fuel consumption rating, combined fuel consumption rating, as well as the dependent variable, CO2 Emissions. By leveraging this dataset, the project aims to estimate the relationship between the dependent variable and more than one independent variable.
#
#
#
# Our underlying hypothesis posits that the variables given in the dataset can be constructively used to predict that there is a highly noticeable linear relationship between some of the independent attributes associated with any vehicle characteristics and the dependent variable carbon dioxide emissions.

# %% [markdown]
# # Phase2: Data Preparation

# %% [markdown]
# The initial focus is to get familiar with the data through cleaning. This involves handling missing values by removing them or estimating what should go in their place. We also need to find and remove any outliers. We will read the selected data, make a list of the different variables, understand what each one measures, see how they relate to each other, and explain what each one means. As part of the cleaning process, inconsistencies, random errors, and empty values were deliberately added since they were not there originally. The goal is to prepare the data for further analysis by addressing issues like missing information and outliers.

# %%
#In this cell, we will employ the pandas library to read the file.
import pandas as pd

# Step 1: Read the original file
df = pd.read_excel("Fuel Consumption Ratings 2023.xlsx")

# Display the dataset
display(df.head())

#display data description
display(df.describe(exclude = "object"))
display(df.describe(include = "object"))
# Out:
#    Year   Make              Model  Vehicle Class  Engine Size (L)  Cylinders  \
# 0  2023  Acura            Integra      Full-size              1.5          4
# 1  2023  Acura     Integra A-SPEC      Full-size              1.5          4
# 2  2023  Acura     Integra A-SPEC      Full-size              1.5          4
# 3  2023  Acura         MDX SH-AWD     SUV: Small              3.5          6
# 4  2023  Acura  MDX SH-AWD Type S  SUV: Standard              3.0          6
#
#   Transmission Fuel Type Fuel Consumption (L/100Km)  Hwy (L/100 km)  \
# 0          AV7         Z                        7.9             6.3
# 1          AV7         Z                        8.1             6.5
# 2           M6         Z                        8.9             6.5
# 3         AS10         Z                12.6L/100Km             9.4
# 4         AS10         Z                      -13.8            11.2
#
#    Comb (L/100 km)  Comb (mpg)  CO2 Emissions (g/km)  CO2 Rating  Smog Rating
# ...

# %%
# To list the fields/variables, and identify their types
data = [
    {"Variable": "Year", "Data Type": "Categorical", "Dependency": "Independent","Using Python": "numerical", "Description": "the year the measurments were taken"},
    {"Variable": "Make", "Data Type": "Nominal", "Dependency": "Independent","Using Python": "categorical","Description": "Manufacturer of the vehicle"},
    {"Variable": "Model", "Data Type": "Nominal", "Dependency": "Independent","Using Python": "categorical", "Description": "Model of the vehicle"},
    {"Variable": "Vehicle Class", "Data Type": "Nominal", "Dependency": "Independent","Using Python": "categorical", "Description": "Class of the vehicle"},
    {"Variable": "Engine Size (L)", "Data Type": "Numeric", "Dependency": "Independent","Using Python": "numerical", "Description": "Engine size in liters"},
    {"Variable": "Cylinders", "Data Type": "Numeric", "Dependency": "Independent","Using Python": "numerical", "Description": "Number of cylinders in the engine"},
    {"Variable": "Transmission", "Data Type": "Nominal", "Dependency": "Independent","Using Python": "categorical", "Description": "Type of transmission"},
    {"Variable": "Fuel Type", "Data Type": "Nominal", "Dependency": "Independent", "Using Python": "categorical", "Description": "Type of fuel used"},
    {"Variable": "Fuel Consumption (L/100Km)", "Data Type": "Numeric", "Dependency": "Independent","Using Python": "numerical", "Description": "Fuel consumption rating in liters/100 km"},
    {"Variable": "Hwy (L/100 km)", "Data Type": "Numeric", "Dependency": "Independent","Using Python": "numerical", "Description": "Highway fuel consumption rating in liters/100 km"},
    {"Variable": "Comb (L/100 km)", "Data Type": "Numeric", "Dependency": "Independent","Using Python": "numerical", "Description": "Combined fuel consumption rating in liters/100 km"},
    {"Variable": "Comb (mpg)", "Data Type": "Numeric", "Dependency": "Independent","Using Python": "numerical", "Description": "Combined fuel consumption rating in mpg"},
    {"Variable": "CO2 Emissions (g/km)", "Data Type": "Numeric", "Dependency": "Dependent","Using Python": "numerical", "Description": "Tailpipe CO2 emissions in g/km"},
    {"Variable": "CO2 Rating", "Data Type": "Ordinal", "Dependency": "Independent","Using Python": "numerical", "Description": "CO2 emissions rating (1-10)"},
    {"Variable": "Smog Rating", "Data Type": "Ordinal", "Dependency": "Independent","Using Python": "numerical", "Description": "Smog emissions rating (1-10)"}
]
 
ndf = pd.DataFrame(data)
display(ndf)



#########################################################################################
#NOTE: - identify variables data types both manually and using python code ...... ex:Fuel Consumption (L/100Km) 
##some mistakes here: 
#Year is integer 
# - Make, Model....... : categorical 
# - in transition we can add this to the desc to make it clear , A transmission is another name for a car's gearbox, the component that turns the engine's power into something the car can use
# - the table in teams can be added to explain some columns (similar to the hw)
# -
# Out:
#                       Variable    Data Type   Dependency Using Python  \
# 0                         Year  Categorical  Independent    numerical
# 1                         Make      Nominal  Independent  categorical
# 2                        Model      Nominal  Independent  categorical
# 3                Vehicle Class      Nominal  Independent  categorical
# 4              Engine Size (L)      Numeric  Independent    numerical
# 5                    Cylinders      Numeric  Independent    numerical
# 6                 Transmission      Nominal  Independent  categorical
# 7                    Fuel Type      Nominal  Independent  categorical
# 8   Fuel Consumption (L/100Km)      Numeric  Independent    numerical
# 9               Hwy (L/100 km)      Numeric  Independent    numerical
# 10             Comb (L/100 km)      Numeric  Independent    numerical
# 11                  Comb (mpg)      Numeric  Independent    numerical
# ...

# %%
# In this step, we will carefully examine the dataset to identify any inconsistencies or instances of missing values.

## Note: as per required in the guidelines we have manipulated the data to demonstrate data cleaning. 

# Display info about the DataFrame
df_info = df.info()

# Check for columns with missing data
null_columns = df.columns[df.isna().any()]

# Printing columns names containing null values if any
if len(null_columns) > 0:
    print("\nColumns with missing data:")
    for i, col in enumerate(null_columns):
        if i < len(null_columns) - 1:
            print(col + ',', end=" ")
        else:
            print(col, end=" ")
    print()
else:
    print("\nThere are no columns with missing data.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        833 non-null    int64
#  1   Make                        818 non-null    object
#  2   Model                       833 non-null    object
#  3   Vehicle Class               833 non-null    object
#  4   Engine Size (L)             833 non-null    float64
#  5   Cylinders                   833 non-null    int64
#  6   Transmission                833 non-null    object
#  7   Fuel Type                   833 non-null    object
#  8   Fuel Consumption (L/100Km)  833 non-null    object
#  9   Hwy (L/100 km)              823 non-null    float64
#  10  Comb (L/100 km)             833 non-null    float64
#  11  Comb (mpg)                  833 non-null    int64
#  12  CO2 Emissions (g/km)        833 non-null    int64
# ...

# %%
##columns Make and Hwy (L/100km) has missing values, hence we will use the imputing approach since there is not alot of missing values.

#Since we have two variables with different data types:

#fill NaN values with mean or mode (modified)
for c in null_columns:
    if df[c].dtype!='object':
        value = df[c].mean()
    else:
        value = df[c].mode()
        value = value[0]  #0 will be the row(s) name
        
    df[c].fillna(value,inplace=True)

display(df.info()) #no null values !
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        833 non-null    int64
#  1   Make                        833 non-null    object
#  2   Model                       833 non-null    object
#  3   Vehicle Class               833 non-null    object
#  4   Engine Size (L)             833 non-null    float64
#  5   Cylinders                   833 non-null    int64
#  6   Transmission                833 non-null    object
#  7   Fuel Type                   833 non-null    object
#  8   Fuel Consumption (L/100Km)  833 non-null    object
#  9   Hwy (L/100 km)              833 non-null    float64
#  10  Comb (L/100 km)             833 non-null    float64
#  11  Comb (mpg)                  833 non-null    int64
#  12  CO2 Emissions (g/km)        833 non-null    int64
# ...

# %%
# Column Fuel Consumption (L/100km) should be classified as float and not object. 
# Based on the head() method a user entered not just the number but the unit as well in Fuel Consumption(L/100Km).
# Also we have noticed a negative values which is not possible.
# Hence, to resolve the inconsistency, we have used this approach:

# To remove the unit entered
df["Fuel Consumption (L/100Km)"] = df["Fuel Consumption (L/100Km)"].apply(
    lambda x: float(x.replace("L/100Km", "")) if type(x) == str else x)

 

# To remove negative values
seleted_cols = df.select_dtypes(exclude='object').columns
df[seleted_cols] = df[seleted_cols].applymap(lambda x: x if x >= 0 else abs(x))

display(df.info())
#display(df.head()) to double check!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        833 non-null    int64
#  1   Make                        833 non-null    object
#  2   Model                       833 non-null    object
#  3   Vehicle Class               833 non-null    object
#  4   Engine Size (L)             833 non-null    float64
#  5   Cylinders                   833 non-null    int64
#  6   Transmission                833 non-null    object
#  7   Fuel Type                   833 non-null    object
#  8   Fuel Consumption (L/100Km)  833 non-null    float64
#  9   Hwy (L/100 km)              833 non-null    float64
#  10  Comb (L/100 km)             833 non-null    float64
#  11  Comb (mpg)                  833 non-null    int64
#  12  CO2 Emissions (g/km)        833 non-null    int64
# ...

# %%
# The variable Year has only one value which is 2023, not helpful, we decided to drop the whole column.
df.drop("Year", axis=1, inplace=True)

# Also, we decided to drop the model column. Since, it has a lot of different values 
df.drop("Model", axis=1, inplace=True)

#display(df.head())

# %%
# Now, we want to locate outliers and remove it:
## We will use boxplot to check outliers
import matplotlib.pyplot as plt
import seaborn as sns

# Identify numeric columns
num_columns = df.select_dtypes(exclude = 'object').columns

# Calculate the number of rows and columns for the grid
num_plots = len(num_columns)
num_rows = int(num_plots ** 0.5)
num_cols = (num_plots // num_rows) + (num_plots % num_rows > 0)

# Create the subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

# Flatten the axes array
axes = axes.flatten()

# Loop through each numeric column and create a boxplot
for i, (c, ax) in enumerate(zip(num_columns, axes)):
    sns.boxplot(y=c, data=df, ax=ax)
    ax.set_title(c)

# Adjust the layout and add a title to the overall figure
plt.tight_layout()
plt.suptitle('BoxPlots Before Removing Outliers', y=1.05)

# Display the plot
plt.show()

# %%
# To find outliers using code 
columns_with_outliers = []

for col in num_columns:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1

    lower_whisker = q1 - 1.5 * iqr
    upper_whisker = q3 + 1.5 * iqr
    
    outliers_mask = (df[col] < lower_whisker) | (df[col] > upper_whisker)
    if any(outliers_mask):
        columns_with_outliers.append(col.capitalize())

if columns_with_outliers:
    columns = ', '.join(columns_with_outliers)
    print(f'There are outliers in the following numerical columns: {columns}')
    
else:
    print('No outliers found in any numerical columns.')
# Out:
# There are outliers in the following numerical columns: Engine size (l), Cylinders, Fuel consumption (l/100km), Hwy (l/100 km), Comb (l/100 km), Comb (mpg), Co2 emissions (g/km), Co2 rating, Smog rating

# %%
# To remove the outliers:

# Identify numeric columns
num_columns = df.select_dtypes(exclude='object').columns


# Remove outliers from each numeric column
for column in num_columns:
    # Calculate the IQR range for the column
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    # Define the lower and upper bounds to identify outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    #drop the rows that contain outliers
    df.drop((df[(df[column] < lower_bound) | (df[column] > upper_bound)]).index,inplace=True,axis=0)

# Draw the updated boxplot without outliers

# Identify numeric columns
num_columns = df.select_dtypes(exclude = 'object').columns

# Calculate the number of rows and columns for the grid
num_plots = len(num_columns)
num_rows = int(num_plots ** 0.5)
num_cols = (num_plots // num_rows) + (num_plots % num_rows > 0)

# Create the subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

# Flatten the axes array
axes = axes.flatten()

# Loop through each numeric column and create a boxplot
for i, (c, ax) in enumerate(zip(num_columns, axes)):
    sns.boxplot(y=c, data=df, ax=ax)
    ax.set_title(c)

# Adjust the layout and add a title to the overall figure
plt.tight_layout()
plt.suptitle('BoxPlots After Removing Outliers', y=1.05)

# Display the plot
plt.show()

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 0 to 832
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Make                        684 non-null    object
#  1   Vehicle Class               684 non-null    object
#  2   Engine Size (L)             684 non-null    float64
#  3   Cylinders                   684 non-null    int64
#  4   Transmission                684 non-null    object
#  5   Fuel Type                   684 non-null    object
#  6   Fuel Consumption (L/100Km)  684 non-null    float64
#  7   Hwy (L/100 km)              684 non-null    float64
#  8   Comb (L/100 km)             684 non-null    float64
#  9   Comb (mpg)                  684 non-null    int64
#  10  CO2 Emissions (g/km)        684 non-null    int64
#  11  CO2 Rating                  684 non-null    int64
#  12  Smog Rating                 684 non-null    int64
# ...

# %% [markdown]
# # Phase 3: Model Planning

# %% [markdown]
# In this phase, we will perform exploratory data analysis (EDA) and model planning for our dataset. The objectives are as follows:
#
# ### a. Run the exploratory data analysis:
# - i) Find the statistical summaries.
# - ii) Make univariate graphs (i.e., graphs based on single variable).
# - iii) Prepare bivariate plots (i.e., plots based on two variables).
# - iv) Portray advanced graphs (i.e., graphs based on more than two variables).
# - v) Assess the relationship between variables.
# ### b. Summarise your findings.

# %% [markdown]
# ##### i) Find the statistical summaries:

# %%
# Find the statistical summaries.

print("\n\033[1mThe statistical summary for numerical data:\033[0m ")
display(df.describe(include='number'))
print("\n",'-'*108, "\n")
print("\n\033[1mThe statistical summary for categorical data:\033[0m ")
display(df.describe(include='object'))
print()
# Out:
# The statistical summary for numerical data:
#        Engine Size (L)   Cylinders  Fuel Consumption (L/100Km)  \
# count       684.000000  684.000000                  684.000000
# mean          2.876754    5.266082                   11.973392
# std           1.028653    1.498449                    2.338147
# min           1.200000    3.000000                    7.100000
# 25%           2.000000    4.000000                   10.100000
# 50%           2.700000    4.000000                   11.800000
# 75%           3.500000    6.000000                   13.600000
# max           5.700000    8.000000                   17.500000
#
#        Hwy (L/100 km)  Comb (L/100 km)  Comb (mpg)  CO2 Emissions (g/km)  \
# count      684.000000       684.000000  684.000000            684.000000
# mean         9.048007        10.657749   27.442982            250.062865
# std          1.704436         1.992324    5.235700             46.385050
# ...

# %% [markdown]
# ##### ii) Make univariate graphs (i.e., graphs based on single variable):

# %%
#the purpose of this step is to observe the distribution of variables
#firsly we will plot histogram plots for non-numerical columns


#import the libraries
from matplotlib import pyplot as plt
import seaborn as sns


# Identify non-numeric columns
categorical_columns = df.drop(columns = ["Make","Transmission"]).select_dtypes(include = 'object').columns



#the number of columns and corresponding rows
num_of_columns = 1
num_of_rows = 2

#adjust the grid
fig,axes = plt.subplots( num_of_columns, num_of_rows,figsize=(30,20))

# Loop through each non-numeric column and create a countplot plots
for (ind,column) in enumerate(categorical_columns):
    sns.countplot(y = column,data=df,ax=axes.flatten()[ind])
    axes.flatten()[ind].set_title(column)

#show the plots
plt.show()

# %% [markdown]
#  - We can estimate the contribution of Vehicle classes and Fuel types by closely examining the countplot graphs. We can see by  that the data includes a variety of vehicle classes; nevertheless, the SUV:Small vehicle class makes up the majority of the data. Additionally, there are four primary gasoline types included in the data; almost half of the sampled cars utilized fuel types Z(premium gasoline) and X(regular gasoline), although relatively few used E(ethanol (E85)) and D(diesel).

# %%
#plot histogram plots for all numerical columns

#import libraries
import matplotlib.pyplot as plt
# %matplotlib inline


# Identify numeric columns
num_columns = df.select_dtypes(exclude = 'object').columns

#calculate the number 
num_plots = len(num_columns)
num_rows = int(num_plots ** 0.5)
num_cols = (num_plots // num_rows) + (num_plots % num_rows > 0)

# Create the subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

# Flatten the axes array
axes = axes.flatten()

# Loop through each numeric column and create a histogram plot
for i, (c, ax) in enumerate(zip(num_columns, axes)):
    sns.histplot(x=c, data=df, ax=ax,kde=True)
    ax.set_title(c)

# Adjust the layout and add a title to the overall figure
plt.tight_layout()
plt.suptitle('Univariate Graphs', y=1.05)

# Display the plot
plt.show()

# %% [markdown]
# By examining all histogram graphs, we observed that the majority of the numerical columns are negatively skewed bell-shaped curves, indicating that most of our variables follow normal distribution. However, some inputs,such as CO2 Rating, Smog Rating,and Cylinders, don't have unique distribution.
# Furthermore, based on the peak value in fuel consumption plot, most of the cars used in the study consumes about 11-12 L/100Km which is not considered as efficient as cars that consume between 5-10L/100Km,. Also the the majority of sampled cars emit 160 g of CO2 per km, however, the emission histogram plot reveal that in general the cars produce between 100-600 g of CO2 in one km. Therefore, most of the sampled cars are not exceptionally low fuel consumption, but it's not extremely high either.

# %% [markdown]
# ##### iii) Prepare bivariate plots (i.e., plots based on two variables).

# %%
#plot categorical columns hued by "Fuel Type"
#import the libraries
from matplotlib import pyplot as plt
import seaborn as sns


# Identify non-numeric columns
categorical_columns = df.drop(columns= ["Make"]).select_dtypes(include = 'object').columns

#the number of columns and corresponding rows
num_of_rows = 2
num_of_columns = 1

#adjust the grid
fig,axes = plt.subplots( num_of_columns, num_of_rows,figsize=(20,20))

# Loop through each non-numeric column and create a countplot plots diffrentiated with "Fuel Type"
for (ind,column) in enumerate(categorical_columns):
    if(column != "Fuel Type"): #to not plot Fuel Type 
        sns.countplot(y = column,data=df,hue ="Fuel Type" ,ax=axes.flatten()[ind])
        axes.flatten()[ind].set_title(column)

#show the plots
plt.show()

# %% [markdown]
# The graph highlights the association between the variables Vehicle class as well as transition with fuel types. We can observe that a few vehicle classes use E(ethanol (E85)) fuel type, whereas Z(premium gasoline) and X ( regular gasoline) types have a minor presencence. Furthermore, there are over 140 SUV: Small vehicles utilize X (regular gasoline) fuel, whereas pickup trucks are the only class that uses E (ethanol (E85)) fuel.
# The transition plot has greater variation than the vehicle classes plot.
# In the fuel type distribution, we can see that Z(premium gasoline) fuel type is used more in AS8 transimition, whereas fuel type E(ethanol (E85)) is has the lowest presencence in transitions.

# %%
#plot histogram plots for all numerical columns

#import libraries
import matplotlib.pyplot as plt
# %matplotlib inline

# Identify numeric columns
num_columns = df.select_dtypes(exclude = 'object').columns

#calculate the number 
num_plots = len(num_columns)
num_rows = int(num_plots ** 0.5)
num_cols = (num_plots // num_rows) + (num_plots % num_rows > 0)

# Create the subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

# Flatten the axes array
axes = axes.flatten()

# Loop through each numeric column and create a histogram plot diffrentiated with "Fuel Type"
##NOTE: other column doesn't make sence
for i, (c, ax) in enumerate(zip(num_columns, axes)):
    sns.histplot(x=c, data=df,hue = "Fuel Type", ax=ax,kde=True)
    ax.set_title(c)

# Adjust the layout and add a title to the overall figure
plt.tight_layout()
plt.suptitle('Univariate Graphs', y=1.05)

# Display the plot
plt.show()

# %%
##plot histogram plots for all numerical columns


#import libraries
import matplotlib.pyplot as plt
# %matplotlib inline

# Identify numeric columns
num_columns = df.select_dtypes(exclude = 'object').columns

#calculate the number 
num_plots = len(num_columns)
num_rows = int(num_plots ** 0.5)
num_cols = (num_plots // num_rows) + (num_plots % num_rows > 0)

# Create the subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

# Flatten the axes array
axes = axes.flatten()

# Loop through each numeric column and create a histogram plot diffrentiated with "Fuel Type"
##NOTE: other column doesn't make sence
for i, (c, ax) in enumerate(zip(num_columns, axes)):
    sns.boxplot(x=c, data=df,y = "Fuel Type", ax=ax)
    ax.set_title(c)

# Adjust the layout and add a title to the overall figure
plt.tight_layout()
plt.suptitle('Univariate Graphs', y=1.05)

# Display the plot
plt.show()

# %% [markdown]
# from the above graphs, we find a relationship between the fuel types and the 3 variables: (Engine size, and the number of cylinders, and fuel consumption).
# we can observe that Z(premium gasoline) and X(regular gasoline) fuel types have large engine size, as well as large number of cylinders, and high fuel consumption, resulting in overall increase in the Co2 emission.

# %%
##Option 1
# plot the dependent variable vs independent variables 

#import libraries
import matplotlib.pyplot as plt
# %matplotlib inline


# Identify numeric columns
num_columns = df.select_dtypes(exclude = 'object').columns

num_rows = 4
num_cols = 2

# Create the subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20,20))

# Flatten the axes array
axes = axes.flatten()

# Loop through each numeric column and create a scatterplot
for i, (c, ax) in enumerate(zip(num_columns, axes)):
    if(c != "CO2 Emissions (g/km)"):
        sns.scatterplot(x='CO2 Emissions (g/km)',y=c, data=df, ax=ax)
        ax.set_title(c)

# Adjust the layout and add a title to the overall figure
plt.tight_layout()
plt.suptitle('bivariate Graphs', y=1.05)

# Display the plot
plt.show()

# %%
##Option 2: 
# plot the dependent variable vs independent variables 

#import libraries
import matplotlib.pyplot as plt
# %matplotlib inline


# Identify numeric columns
num_columns = df.drop(columns = ["CO2 Emissions (g/km)"]).select_dtypes(exclude = 'object').columns

# num_rows = 4
# num_cols = 2

# Create the subplots
# fig, axes = plt.subplots(num_rows, num_cols, figsize=(20,20))

# Flatten the axes array
# axes = axes.flatten()

# Loop through each numeric column and create a scatterplot
sns.pairplot(vars=num_columns,hue ='CO2 Emissions (g/km)',data=df)
# Adjust the layout and add a title to the overall figure
# plt.tight_layout()
plt.suptitle('bivariate Graphs', y=1.05)

# Display the plot
plt.show()

# %% [markdown]
# The plots above clearly show the relationships between the variables and the Co2 emission. From our observation HWy, fuel consumption, and comb L/100km form a nearly perfect linear relationship. Moreover, the sampled cars that have 6 Co2 rating emit the lowest amount of Co2 while car with rating 1 emit more than 600g/km.
# The Comb(mpg) plot is opposite to Comb(L/100km) although they are the same type. The reason is that they have different units which are opposite, Comb(L/100km) is volume per unit distance while Comb(mpg) is distance per unit volume, therefore, opposite graphs is expected.

# %%
df["CO2 Rating"].unique()
# Out:
# array([6, 4, 5, 3], dtype=int64)

# %% [markdown]
# #### iv) Portray advanced graphs (i.e., graphs based on more than two variables).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
sns.barplot(y='CO2 Emissions (g/km)',data=df,x='Cylinders',hue='Fuel Type')
plt.title('Cylinders VS CO2 emissions differentiated by Fuel Type')
plt.show()

# %% [markdown]
# The graph depicting CO2 emissions in relation to the number of cylinders and fuel type reveals a notable trend.
# The observation indicates that as the number of cylinders in a vehicle increases, so does its carbon dioxide emissions which means that a higher cylinder count may tend to burn more fuel, resulting in increased emissions. Notably, the data highlights that vehicles with 8 cylinders exhibit the highest emissions among the observed groups, especially with type x fuel.

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(size='Engine Size (L)',sizes=(20,300), x='Fuel Consumption (L/100Km)', y='CO2 Emissions (g/km)', data=df)

plt.title('Fuel Consumption VS CO2 emissions differentiated by Engine size')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(hue='Cylinders',size = "Cylinders", x='Fuel Consumption (L/100Km)', y='CO2 Emissions (g/km)', data=df)

plt.title('Fuel Consumption VS CO2 emissions differentiated by Cylinders')
plt.show()

# %% [markdown]
# - Fuel Consumption VS CO2 emissions differentiated by Engine size
# The graph illustrating the relationship between CO2 emissions and fuel consumption, categorized by engine size, reveals a discernible pattern. The observation suggests that there is a positive correlation between engine size and both fuel consumption and CO2 emissions. As the engine size increases, there is a noticeable uptick in fuel consumption, indicating that larger engines tend to burn more fuel. Concurrently, this increase in fuel consumption corresponds with elevated CO2 emissions. This correlation underscores the impact of engine size on a vehicle's footprint, highlighting the importance of considering engine sizes when evaluating emissions.
#
# - Fuel Consumption VS CO2 emissions differentiated by Cylinders
# There's a clear trend in the graph that shows the correlation between CO2 emissions and fuel consumption by the numbers of cylinders. According to the finding, cylinders and CO2 emissions as well as fuel consumption are positively correlated. As the cylinders number increase, there is a noticeable increase in the fuel consumption as well as Co2 emission, suggesting that the more cylinders used typically will use more power, resulting in more consumption of CO2 and more Co2 emission. This relationship emphasizes how the number of cylinders used in the car affects the CO2 emission and shows how important it is to take cylinders number into account when assessing emissions.

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\dnoo9\AppData\Local\Temp\ipykernel_25128\2239516573.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().style.background_gradient(cmap='coolwarm')
# <style type="text/css">
# #T_259c8_row0_col0, #T_259c8_row1_col1, #T_259c8_row2_col2, #T_259c8_row3_col3, #T_259c8_row4_col4, #T_259c8_row5_col5, #T_259c8_row6_col6, #T_259c8_row7_col7, #T_259c8_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_259c8_row0_col1, #T_259c8_row1_col0, #T_259c8_row5_col7, #T_259c8_row7_col5 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_259c8_row0_col2 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_259c8_row0_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_259c8_row0_col4, #T_259c8_row2_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ##### v) Assess the relationship between variables.

# %% [markdown]
# The analysis of the correlation matrix provides valuable insights into the interrelationships among various automotive  numerical variables. Focusing on the key variable "CO2 Emissions (g/km)," the exploration reveals discernible patterns:
#
# #### CO2 Emissions (g/km) vs. Engine Size (L):
#
# There is a positive correlation, indicating that larger engine sizes are associated with higher CO2 emissions. This means that larger engines often burn more fuel, leading to increased emissions.
#
# #### CO2 Emissions (g/km) vs. Cylinders:
# There is a positive correlation, suggesting that a higher number of cylinders is associated with higher CO2 emissions.
#
#
# #### CO2 Emissions (g/km) vs. Fuel Consumption (L/100Km):
#
# There is a strong positive correlation, indicating that as fuel consumption increases, CO2 emissions also increase. This relationship is expected since burning more fuel results in higher emissions.
#
# #### CO2 Emissions (g/km) vs. Comb (mpg):
#
# There is a strong negative correlation, suggesting that as fuel efficiency (measured in miles per gallon) increases, CO2 emissions decrease. Vehicles with higher fuel efficiency tend to produce fewer emissions.
#
# #### CO2 Emissions (g/km) vs. CO2 Rating:
# There is a strong negative correlation, implying that vehicles with higher CO2 ratings tend to have lower CO2 emissions. Thismeans that vehicles with better environmental ratings produce fewer emissions.

# %% [markdown]
# ### Findings:

# %% [markdown]
# - CO2 Emissions (g/km) has a positive correlation with Engine Size (L), indicating larger engine sizes are associated with higher emissions.
#
# - CO2 Emissions (g/km) shows a positive correlation with the number of Cylinders, suggesting more cylinders leads to higher emissions.
#
# - A strong positive correlation exists between CO2 Emissions (g/km) and Fuel Consumption (L/100km), where increased fuel use results in increased emissions.
#
# - CO2 Emissions (g/km) has a strong negative correlation with Comb (mpg), meaning higher fuel efficiency corresponds to lower emissions.
#
# - CO2 Emissions (g/km) is strongly negatively correlated with CO2 Rating, implying vehicles with better environmental ratings have lower emissions levels.
#
# - Relationships identified align with intuition, such as larger engines/more cylinders and higher fuel consumption relating to increased emissions.
#
# - Key variable interactions informed by correlations can help build predictive models to estimate CO2 based on other attributes.
#
# - Valuable visual and statistical analyses from EDA phase will guide feature selection and modeling in subsequent phases.

# %% [markdown]
# # Phase 4: Model Building

# %% [markdown]
# In an era where environmental awareness is important, understanding and reducing the impact of vehicular CO2 emissions is a critical endeavor. This project addresses the pressing need for accurate prediction and classification of CO2 emissions based on a diverse set of automotive features. The ultimate goal is to develop a best-fit machine learning model that can effectively identify and classify the level of CO2 emissions associated with various vehicles.
#
# ---
#
#
# ***The reason why did we chose regression for our model:***
# regression models were chosen for the CO2 emissions modeling due to the continuous numeric nature of the target variable "CO2 emissions". This approach allows us to predict and quantify emissions based on various independent automotive features.
#
# ---
#
# **Models Used:**
# We have chosen three popular and effective regression models to test:
# - Ordinary Least Squares
# - Ridge
# - Lasso

# %%
import pandas as pd

ndf=df.drop(['Transmission','Make','Vehicle Class'],axis=1) # Drop irrelevant categorical features

# we will drop one of the 'Comb' columns since we have two columns with the same information but in different units 
#to avoid redundancy and simplify the analysis
ndf.drop(['Comb (mpg)'],axis=1,inplace=True)
display(ndf)
# Out:
#      Engine Size (L)  Cylinders Fuel Type  Fuel Consumption (L/100Km)  \
# 0                1.5          4         Z                         7.9
# 1                1.5          4         Z                         8.1
# 2                1.5          4         Z                         8.9
# 3                3.5          6         Z                        12.6
# 4                3.0          6         Z                        13.8
# ..               ...        ...       ...                         ...
# 828              2.0          4         Z                        10.2
# 829              2.0          4         Z                        10.3
# 830              2.0          4         Z                        11.1
# 831              2.0          4         Z                        10.5
# 832              2.0          4         Z                        11.9
#
#      Hwy (L/100 km)  Comb (L/100 km)  CO2 Emissions (g/km)  CO2 Rating  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder() # Initialize a LabelEncoder
ndf['Fuel Type'] = label_encoder.fit_transform(ndf['Fuel Type']) # to transform the 'Fuel Type' column from categorical to numerical as the model building requires numerical inputs

display(ndf)
# Out:
#      Engine Size (L)  Cylinders  Fuel Type  Fuel Consumption (L/100Km)  \
# 0                1.5          4          3                         7.9
# 1                1.5          4          3                         8.1
# 2                1.5          4          3                         8.9
# 3                3.5          6          3                        12.6
# 4                3.0          6          3                        13.8
# ..               ...        ...        ...                         ...
# 828              2.0          4          3                        10.2
# 829              2.0          4          3                        10.3
# 830              2.0          4          3                        11.1
# 831              2.0          4          3                        10.5
# 832              2.0          4          3                        11.9
#
#      Hwy (L/100 km)  Comb (L/100 km)  CO2 Emissions (g/km)  CO2 Rating  \
# ...

# %%
from sklearn.model_selection import train_test_split
import numpy as np


# 'X' contains the features, excluding the 'CO2 Emissions (g/km)' column
# 'y' contains the target variable, which is the 'CO2 Emissions (g/km)' column
X = ndf.drop(['CO2 Emissions (g/km)'],axis=1)
y = ndf['CO2 Emissions (g/km)']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=40)

# %%
# Scaling the Train - Test splits
import numpy as np
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler.fit(np.c_[X_train,y_train]) # Fit the scaler on the training data

# Transform the features and target variable in the X_train and y_train sets
A_train = scaler.transform(np.c_[X_train,y_train])
X_train = A_train[:,:-1]
y_train = A_train[:,-1]

# Transform the features and target variable in the X_test and y_test
A_test = scaler.transform(np.c_[X_test,y_test])
X_test = A_test[:,:-1]
y_test = A_test[:,-1]

# %%
## OLS
from sklearn.linear_model import LinearRegression

# Initialize a LinearRegression and fit the model on the training data
reg1 = LinearRegression(fit_intercept=False).fit(X_train, y_train)
best_beta = np.round(reg1.coef_,2) #the best values for the coefficients

print(f'Trying OLS Regression:')
print(f'The best values for the estimates are :', best_beta.tolist())
# Out:
# Trying OLS Regression:
# The best values for the estimates are : [-0.03, 0.05, -0.05, 0.28, 0.19, 0.36, -0.16, -0.03]

# %%
## Ridge
from sklearn.linear_model import RidgeCV

# Initialize a LinearRegression and fit the model on the training data
reg2 = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2, 1e3], fit_intercept=False,cv=10).fit(X_train, y_train)
best_beta=np.round(reg2.coef_,2) #the best values for the coefficients

print(f'Trying Ridge Regression:')
print(f'The best values for the estimates are :', best_beta.tolist())
# Out:
# Trying Ridge Regression:
# The best values for the estimates are : [-0.01, 0.04, -0.04, 0.29, 0.22, 0.28, -0.18, -0.04]

# %%
## Lasso
from sklearn.linear_model import LassoCV

# Initialize a LinearRegression and fit the model on the training data
reg3 = LassoCV(alphas=[1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2, 1e3],fit_intercept=False,cv=10, random_state=0).fit(X_train, y_train)
best_beta=np.round(reg3.coef_,2)#the best values for the coefficients

print(f'Trying Lasso Regression:')
print(f'The best values for the estimates are :', best_beta.tolist())
# Out:
# Trying Lasso Regression:
# The best values for the estimates are : [0.0, 0.02, -0.04, 0.21, 0.15, 0.45, -0.17, -0.03]
# C:\Users\dnoo9\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07967791389571754, tolerance: 0.043734072259751
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\dnoo9\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04600370201421278, tolerance: 0.041717150201309755
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\dnoo9\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07435406367523445, tolerance: 0.0423869567205388
# ...

# %% [markdown]
# #### Observations besed on the coefficients:
# - OLS provides non-zero coefficients for most features
# - Ridge Regression tends to shrink the coefficients due to the penalty term, and some are reduced compared to OLS.
# - Lasso Regression tends to reduce some coefficients which are 'Engine Size (L)' and 'Fuel Type	' to exactly zero. It implies that these features with zero coefficients are considered less relevant or have a negligible impact on predicting the target variable.

# %%
# Choosing the Best Model
# Regression Analysis: Mean Squared Error Metric
from sklearn.metrics import mean_squared_error

y_pred1 = reg1.predict(X_test) # Predictions using OLS
print('The MSE using OLS is:', mean_squared_error(y_test, y_pred1))

y_pred2 = reg2.predict(X_test) # Predictions using Ridge
print('The MSE using Ridge is:', mean_squared_error(y_test, y_pred2))

y_pred3 = reg3.predict(X_test) # Predictions using Lasso
print('The MSE using Lasso is:', mean_squared_error(y_test, y_pred3))
print('-'*80)
print("These values represent the average squared differences between the predicted and actual CO2 emissions. In this case, the Ridge Regression model has the lowest MSE, suggesting it performs slightly better on the test set compared to OLS and Lasso.")
# Out:
# The MSE using OLS is: 0.045553913167603724
# The MSE using Ridge is: 0.04341982076447696
# The MSE using Lasso is: 0.04452057824847953
# --------------------------------------------------------------------------------
# These values represent the average squared differences between the predicted and actual CO2 emissions. In this case, the Ridge Regression model has the lowest MSE, suggesting it performs slightly better on the test set compared to OLS and Lasso.

# %% [markdown]
# ### Findings:

# %% [markdown]
# The analysis of the data-driven CO2 emissions prediction revealed valuable insights about the performance of various models and affirmed the validity of our hypothesis through a comprehensive analysis of these models, where our hypothesis states that some of the input features provided in the dataset can be effectively utilized to predict the amount of CO2 emitted by a vehicle. Among the three models evaluated, the Ridge regression emerged as the most promising choice, showing the lowest Mean Squared Error of 0.03422681215002337.

# %% [markdown]
# ##### the details of the final selected model:

# %%
## Details of the best estimates
print('Ridge regression:')
print()
print('- The best penalty coefficient is:', reg2.alpha_)
print('- The best coefficient estimates are:', reg2.coef_.tolist())
print('- Mean Squared Error (MSE)=', mean_squared_error(y_test, y_pred2),'\n')
print("Interpretation of the coefficients:")
print('- Coefficients represent the impact of each predictor variable on CO2 emissions.')
print('- Positive coefficients suggest a positive relationship, while negative coefficients indicate a negative relationship.')
print('- The magnitude of coefficients reflects the strength of the impact.')
# Out:
# Ridge regression:
#
# - The best penalty coefficient is: 10.0
# - The best coefficient estimates are: [-0.010880341236177848, 0.044709640909130155, -0.044809823149151815, 0.29285797943211145, 0.2232082131249122, 0.2754760096305864, -0.17627180182682062, -0.035925675812014994]
# - Mean Squared Error (MSE)= 0.04341982076447696
#
# Interpretation of the coefficients:
# - Coefficients represent the impact of each predictor variable on CO2 emissions.
# - Positive coefficients suggest a positive relationship, while negative coefficients indicate a negative relationship.
# - The magnitude of coefficients reflects the strength of the impact.

# %% [markdown]
# # Phase 5: Communicate Results

# %% [markdown]
# ### Summary and Conclusion:
#
# - Discovery:
# The project started with the exploration of a dataset containing information on fuel consumption ratings and estimated carbon dioxide emissions for new vehicles. The primary problem addressed was the environmental impact of fuel consumption, especially in relation to climate change. The objective was to analyze the dataset's attributes, such as engine size, cylinders, transmission, and fuel type, to estimate the relationship with carbon dioxide emissions.
#
#
# - Results and Recommendations:
# The Ridge regression model stood out as the most promising choice, demonstrating the lowest MSE. The best estimates from Ridge regression indicated the impact of predictor variables on CO2 emissions.
#
# - major insight and finding:
# 1- Consider Engine Size and Cylinders: Larger engine sizes and a higher number of cylinders tend to contribute to higher carbon dioxide emissions. Manufacturers and consumers should be aware of these factors when making decisions about vehicle models.
#
# 2- Promote Fuel Efficiency: The analysis revealed a strong negative correlation between fuel efficiency (measured in miles per gallon) and CO2 emissions. Encouraging the production and use of fuel-efficient vehicles can contribute to lower emissions.
#
# 3- Environmental Ratings: Vehicles with higher CO2 ratings tended to have lower emissions. Therefore, promoting and considering vehicles with better environmental ratings can be an effective strategy in reducing overall carbon dioxide emissions.

# %% [markdown]
# ### Future Recommendations
# 1- Consider expanding the dataset to include more recent information and additional variables that may influence carbon dioxide emissions, such as hybrid or electric vehicle technology.
#
#
# 2- Continuously refine and optimize the chosen model (Ridge regression) as more data becomes available. This may involve adjusting hyperparameters or exploring more advanced machine learning techniques.
#
#
# 3- Share the findings with policymakers to inform potential regulations or incentives aimed at reducing carbon emissions from the automotive sector.
#
#
# 4- Educate consumers about the environmental impact of their vehicle choices, emphasizing factors such as engine size, cylinders, and fuel efficiency.

# %% [markdown]
# # Phase 6: Operationalize

# %% [markdown]
# ### General guidelines to adopt methodology:
#
# This model serves as a valuable tool for predicting CO2 emissions by analyzing input features like engine size, cylinders, transmission, and fuel type. Its application in the development process enables car manufacturing companies to create eco-friendly vehicles with reduced CO2 emissions. By meeting the rising consumer demand for environmentally conscious products, businesses can enhance their market presence and competitiveness, aligning with the growing trend toward sustainable and eco-friendly transportation solutions.
#
#
#
# problems and issues in the implementation of the methodology:
#
#
#
# 1.In broad terms, our data evaluation has been confined to a restricted range of fuel types. Given the increasing prevalence of hybrid vehicles in many companies, it's worth noting that this model may not be applicable to such hybrid car implementations.
#
#
#
# 2.The model may not account for all factors influencing CO2 emissions.
#
#
#
# 3.Real world data may vary in quality consistency, and format. As in the model may struggle to perform well if the incoming data differs significantly from the training data.

# %% [markdown]
# ### Problems and Issues in Implementation:
# Inconsistent Comb Units:
# - There were two columns of the same variable except for different units. We struggled at first to why one of them would appear increasing while the other one is decreasing.
# - After further research, we came into realisation that the first variable (L per Km) is the opposite to the second one (miles per gallon); hence, the graphs are indeed consistent.
#
#
#
# When removing the outliers:
# - the code implemented would only update the last column, only the outliers in the last iterative loop would be removed.
# - simply fix was to use df.drop instead of df =
